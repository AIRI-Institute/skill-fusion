# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import sys
sys.path.append('habitat_map/utils_f')
import depth_utils as du

# %%
pcd = np.load('pointcloud_0.npz')['arr_0'].reshape((640 * 480, 3))
pcd15 = np.load('pointcloud_15.npz')['arr_0'].reshape((640 * 480, 3))
#pcd_trans = np.load('pointcloud_transformed.npz')['arr_0'].reshape((640 * 480, 3))
pcd_trans = du.transform_camera_view(pcd15, 1.31, -30)

# %%
plt.figure(figsize=(20, 8))
plt.subplot(1, 3, 1)
plt.scatter(pcd[::17, 0], pcd[::17, 1], s=5, alpha=0.1)
plt.subplot(1, 3, 2)
plt.scatter(pcd15[::17, 0], pcd15[::17, 1], s=5, alpha=0.1)
plt.subplot(1, 3, 3)
plt.scatter(pcd_trans[::17, 0], pcd_trans[::17, 1], s=5, alpha=0.1)
